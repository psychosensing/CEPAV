# %%
# Moments - S1:
# Baseline 1,2,3,4,5 minute (Marker name: 1), 
# Before the 1st match 1st minute (11), 
# Before the 1st match 2nd minute (12), 
# During the match 1st minute (13), 
# During the match 2nd minute (14), 
# After the 1st match 1st minute (15), 
# After the 1st match 2nd minute, (15)
# and similarly for the 2nd and 3rd matches -   
# a total of 23 one-minute intervals from S1 (5 from the baseline and 6 from each match).

# %%
# %pip install neurokit2

# %%
import neurokit2 as nk
import pandas as pd
import os

# %% [markdown]
# Columns for each channel

# %%
hr_cols = ["baseline_visit1__min1_hr", "baseline_visit1__min2_hr", "baseline_visit1__min3_hr", "baseline_visit1__min4_hr", "baseline_visit1__min5_hr", "training1_baseline_min1_hr", "training1_baseline_min2_hr", "training1_gameplay_min1_hr", "training1_gameplay_min2_hr", "training1_revery_min1_hr", "training1_revery_min2_hr", "training2_baseline_min1_hr", "training2_baseline_min2_hr", "training2_gameplay_min1_hr", "training2_gameplay_min2_hr", "training2_revery_min1_hr", "training2_revery_min2_hr", "training3_baseline_min1_hr", "training3_baseline_min2_hr", "training3_gameplay_min1_hr", "training3_gameplay_min2_hr", "training3_revery_min1_hr", "training3_revery_min2_hr"]

# %%
hrv_cols = ["baseline_visit1__min1_hrv", "baseline_visit1__min2_hrv", "baseline_visit1__min3_hrv", "baseline_visit1__min4_hrv", "baseline_visit1__min5_hrv", "training1_baseline_min1_hrv", "training1_baseline_min2_hrv", "training1_gameplay_min1_hrv", "training1_gameplay_min2_hrv", "training1_revery_min1_hrv", "training1_revery_min2_hrv", "training2_baseline_min1_hrv", "training2_baseline_min2_hrv", "training2_gameplay_min1_hrv", "training2_gameplay_min2_hrv", "training2_revery_min1_hrv", "training2_revery_min2_hrv", "training3_baseline_min1_hrv", "training3_baseline_min2_hrv", "training3_gameplay_min1_hrv", "training3_gameplay_min2_hrv", "training3_revery_min1_hrv", "training3_revery_min2_hrv"]

# %%
sbp_cols = ["baseline_visit1__min1_SBP", "baseline_visit1__min2_SBP", "baseline_visit1__min3_SBP", "baseline_visit1__min4_SBP", "baseline_visit1__min5_SBP", "training1_baseline_min1_SBP", "training1_baseline_min2_SBP", "training1_gameplay_min1_SBP", "training1_gameplay_min2_SBP", "training1_revery_min1_SBP", "training1_revery_min2_SBP", "training2_baseline_min1_SBP", "training2_baseline_min2_SBP", "training2_gameplay_min1_SBP", "training2_gameplay_min2_SBP", "training2_revery_min1_SBP", "training2_revery_min2_SBP", "training3_baseline_min1_SBP", "training3_baseline_min2_SBP", "training3_gameplay_min1_SBP", "training3_gameplay_min2_SBP", "training3_revery_min1_SBP", "training3_revery_min2_SBP"]

# %%
dbp_cols = ["baseline_visit1__min1_DBP", "baseline_visit1__min2_DBP", "baseline_visit1__min3_DBP", "baseline_visit1__min4_DBP", "baseline_visit1__min5_DBP", "training1_baseline_min1_DBP", "training1_baseline_min2_DBP", "training1_gameplay_min1_DBP", "training1_gameplay_min2_DBP", "training1_revery_min1_DBP", "training1_revery_min2_DBP", "training2_baseline_min1_DBP", "training2_baseline_min2_DBP", "training2_gameplay_min1_DBP", "training2_gameplay_min2_DBP", "training2_revery_min1_DBP", "training2_revery_min2_DBP", "training3_baseline_min1_DBP", "training3_baseline_min2_DBP", "training3_gameplay_min1_DBP", "training3_gameplay_min2_DBP", "training3_revery_min1_DBP", "training3_revery_min2_DBP"]

# %%
co_cols = ["baseline_visit1__min1_CO", "baseline_visit1__min2_CO", "baseline_visit1__min3_CO", "baseline_visit1__min4_CO", "baseline_visit1__min5_CO", "training1_baseline_min1_CO", "training1_baseline_min2_CO", "training1_gameplay_min1_CO", "training1_gameplay_min2_CO", "training1_revery_min1_CO", "training1_revery_min2_CO", "training2_baseline_min1_CO", "training2_baseline_min2_CO", "training2_gameplay_min1_CO", "training2_gameplay_min2_CO", "training2_revery_min1_CO", "training2_revery_min2_CO", "training3_baseline_min1_CO", "training3_baseline_min2_CO", "training3_gameplay_min1_CO", "training3_gameplay_min2_CO", "training3_revery_min1_CO", "training3_revery_min2_CO"]

# %%
tpr_cols = ["baseline_visit1__min1_TPR", "baseline_visit1__min2_TPR", "baseline_visit1__min3_TPR", "baseline_visit1__min4_TPR", "baseline_visit1__min5_TPR", "training1_baseline_min1_TPR", "training1_baseline_min2_TPR", "training1_gameplay_min1_TPR", "training1_gameplay_min2_TPR", "training1_revery_min1_TPR", "training1_revery_min2_TPR", "training2_baseline_min1_TPR", "training2_baseline_min2_TPR", "training2_gameplay_min1_TPR", "training2_gameplay_min2_TPR", "training2_revery_min1_TPR", "training2_revery_min2_TPR", "training3_baseline_min1_TPR", "training3_baseline_min2_TPR", "training3_gameplay_min1_TPR", "training3_gameplay_min2_TPR", "training3_revery_min1_TPR", "training3_revery_min2_TPR"]

# %%
wr_cols = ["baseline_visit1__min1_wr", "baseline_visit1__min2_wr", "baseline_visit1__min3_wr", "baseline_visit1__min4_wr", "baseline_visit1__min5_wr", "training1_baseline_min1_wr", "training1_baseline_min2_wr", "training1_gameplay_min1_wr", "training1_gameplay_min2_wr", "training1_revery_min1_wr", "training1_revery_min2_wr", "training2_baseline_min1_wr", "training2_baseline_min2_wr", "training2_gameplay_min1_wr", "training2_gameplay_min2_wr", "training2_revery_min1_wr", "training2_revery_min2_wr", "training3_baseline_min1_wr", "training3_baseline_min2_wr", "training3_gameplay_min1_wr", "training3_gameplay_min2_wr", "training3_revery_min1_wr", "training3_revery_min2_wr"]

# %%
tl_cols = ["baseline_visit1__min1_tl", "baseline_visit1__min2_tl", "baseline_visit1__min3_tl", "baseline_visit1__min4_tl", "baseline_visit1__min5_tl", "training1_baseline_min1_tl", "training1_baseline_min2_tl", "training1_gameplay_min1_tl", "training1_gameplay_min2_tl", "training1_revery_min1_tl", "training1_revery_min2_tl", "training2_baseline_min1_tl", "training2_baseline_min2_tl", "training2_gameplay_min1_tl", "training2_gameplay_min2_tl", "training2_revery_min1_tl", "training2_revery_min2_tl", "training3_baseline_min1_tl", "training3_baseline_min2_tl", "training3_gameplay_min1_tl", "training3_gameplay_min2_tl", "training3_revery_min1_tl", "training3_revery_min2_tl"]

# %%
tr_cols = ["baseline_visit1__min1_tr", "baseline_visit1__min2_tr", "baseline_visit1__min3_tr", "baseline_visit1__min4_tr", "baseline_visit1__min5_tr", "training1_baseline_min1_tr", "training1_baseline_min2_tr", "training1_gameplay_min1_tr", "training1_gameplay_min2_tr", "training1_revery_min1_tr", "training1_revery_min2_tr", "training2_baseline_min1_tr", "training2_baseline_min2_tr", "training2_gameplay_min1_tr", "training2_gameplay_min2_tr", "training2_revery_min1_tr", "training2_revery_min2_tr", "training3_baseline_min1_tr", "training3_baseline_min2_tr", "training3_gameplay_min1_tr", "training3_gameplay_min2_tr", "training3_revery_min1_tr", "training3_revery_min2_tr"]

# %%
bunch = [hr_cols, hrv_cols, sbp_cols, dbp_cols, co_cols, tpr_cols, wr_cols, tl_cols, tr_cols]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def process_hr_hrv(file_path, bunch_of_cols, filename):
       """
    Process heart rate (HR) and heart rate variability (HRV) data from ECG signals.

    Parameters:
    file_path (str): The path to the CSV file containing the ECG data.
    bunch_of_cols (list): A list of lists where each sublist contains column names for HR and HRV data.
    filename (str): The name of the file to be used as the index for the resulting DataFrame.

    Returns:
    pd.DataFrame: A DataFrame with processed HR and HRV data. The index is based on the provided filename,
                  and the columns are defined by the input `bunch_of_cols`.
    """
    i = 0
    bn_col = 0
    df_sub = pd.read_csv(file_path)
    markers = [1, 11, 12, 13, 14, 15, 16, 21, 22, 23, 24, 25, 26, 31, 32, 33, 34, 35, 36] #procedure markers, needed to mark the start of the average counting moment for each interval.
                                                                    #for marker "1" there are 5 columns from each set with the label "baseline". For the next markers there is a single column. A total of 19 markers and 23 moments.
    dataframes = []
    hr_hrv_cols = [col for sublist in bunch_of_cols[:2] for col in sublist] #extracting the first two sets of columns from bunch (hr and hrv)
    df_hr = pd.DataFrame(columns=hr_hrv_cols)
    df_hr.loc[0] = [None] * len(hr_hrv_cols) 
    
    if bn_col == 0:
        for marker in markers:
            curr_idx = df_sub.index[df_sub['marker'] == marker] #determining the first index for the given marker in df
            if marker == 1:
                for y in range(0, 300000, 60000): #calculations initiated from a 5-minute baseline, with minute intervals
                    ecg_signals, info = nk.ecg_process(df_sub["ECG"].iloc[curr_idx[0]+y:curr_idx[0]+y+60000], sampling_rate=1000) #calculating minute intervals hr from the first found index based on the marker, with a sampling rate of 1000hz
                    hr = nk.ecg_intervalrelated(ecg_signals).iloc[0, 0]
                    df_hr.iloc[0, i] = hr #saving calculations in local df
                    i += 1 #moving to the next column
            else:
                ecg_signals, info = nk.ecg_process(df_sub["ECG"].iloc[curr_idx[0]:curr_idx[0]+60000], sampling_rate=1000)
                hr = nk.ecg_intervalrelated(ecg_signals).iloc[0, 0]
                df_hr.iloc[0, i] = hr
                i += 1
        bn_col += 1
    
    if bn_col == 1:
        for marker in markers:
            curr_idx = df_sub.index[df_sub['marker'] == marker]
            if marker == 1:
                for y in range(0, 300000, 60000): #similarly for hrv
                    ecg_signals, info = nk.ecg_process(df_sub["ECG"].iloc[curr_idx[0]+y:curr_idx[0]+y+60000], sampling_rate=1000)
                    hrv = nk.ecg_intervalrelated(ecg_signals).iloc[0, 9]
                    df_hr.iloc[0, i] = hrv
                    i += 1
            else:
                ecg_signals, info = nk.ecg_process(df_sub["ECG"].iloc[curr_idx[0]:curr_idx[0]+60000], sampling_rate=1000)
                hrv = nk.ecg_intervalrelated(ecg_signals).iloc[0, 9]
                df_hr.iloc[0, i] = hrv
                i += 1
    
    df_hr.index = [filename.replace('.csv', '')] #saving to df with the subject's id as the index name
    return df_hr

def process_others(df, file_path, bunch_of_cols, filename):        
     """
    Process blood pressure channels together with accelerometers data and merge with the existing DataFrame.

    Parameters:
    df (pd.DataFrame): The existing DataFrame with calculated hr and hrv means to merge new data into.
    file_path (str): The path to the CSV file containing the data.
    bunch_of_cols (list): A list of lists where each sublist contains column names for the different physiological metrics.
    filename (str): The name of the file to be used as the index for the resulting DataFrame.

    Returns:
    pd.DataFrame: A DataFrame with the processed data merged into the input DataFrame `df`.
                  The index is based on the provided filename, and the columns are defined by the input `bunch_of_cols`.
    """
    i = 0
    bn_col = 0
    df_sub = pd.read_csv(file_path, usecols=['SBP', 'DBP', 'CO', 'TPR', 'wr', 'tl', 'tr', 'marker'])
    markers = [1, 11, 12, 13, 14, 15, 16, 21, 22, 23, 24, 25, 26, 31, 32, 33, 34, 35, 36]
    dataframes = []
    for set_cols in bunch_of_cols[2:]: #selecting sets of columns excluding hr and hrv
        df_temp = pd.DataFrame(columns=set_cols)
        df_temp.loc[0] = [None] * len(set_cols)
        for marker in markers:
            curr_idx = df_sub.index[df_sub['marker'] == marker]
            if marker == 1:
                for y in range(0, 300000, 60000):
                    df_sub_means = df_sub.iloc[curr_idx[0]+y:curr_idx[0]+60000+y, :-1].mean().iloc[bn_col] #calculating the average for minute fragments of the baseline
                    df_temp.iloc[0, i] = df_sub_means #incorporating data into df in the correct place
                    i += 1 #moving to the next column 
            else:
                df_sub_means = df_sub.iloc[curr_idx[0]:curr_idx[0]+60000, :-1].mean().iloc[bn_col]
                df_temp.iloc[0, i] = df_sub_means
                i += 1
        dataframes.append(df_temp) #collecting dataframes into a list
        bn_col += 1
        i = 0
    
    df_final = pd.concat(dataframes, axis=1) #merging df with calculated hr and hrv with the list of calculated dfs from the averages of blood pressure and accelerometers
    df_final.index = [filename.replace('.csv', '')]
    
    df_merged = df.join(df_final, how='outer')
    return df_merged

# Processing all CSV files in the folder
input_folder = '/home/ubuntu/eSportData/jupyter-data/VU_AMS/s1_output/'
output_df = pd.DataFrame()

for file_name in os.listdir(input_folder): #iterating through the list with the databases of the subjects
    print(file_name)
    if file_name.endswith('.csv'):
        try:
            file_path = os.path.join(input_folder, file_name)
            processed_df = process_hr_hrv(file_path, bunch, file_name) #calling the function to create df with calculated hr and hrv averages
            final_df = process_others(processed_df, file_path, bunch, file_name) #calling the function to calculate blood pressure and accelerometer averages and merge them with hr and hrv into a common df
            output_df = pd.concat([output_df, final_df]) #adding the subject's data from the iteration to the collective df with other subjects
        except:
            pass

# Saving the resulting DataFrame to a CSV file
output_df.to_csv('/home/ubuntu/eSportData/jupyter-data/VU_AMS/processed_means_s1_v3_patched.csv')
# Out:
# S1_p152.csv
# S1_p125.csv
# S1_p93.csv
# S1_p21.csv
# S1_p108.csv
# S1_p216.csv
# S1_p255.csv
# S1_p84.csv
# S1_p157.csv
# S1_p159.csv
# S1_p123.csv
# S1_p266.csv
# S1_p42.csv
# S1_p82.csv
# S1_p97.csv
# S1_p130.csv
# S1_p158.csv
# S1_p221.csv
# S1_p99.csv
# S1_p29.csv
# S1_p63.csv
# S1_p22.csv
# S1_p79.csv
# S1_p182.csv
# S1_p92.csv
# S1_p136.csv
# S1_p176.csv
# S1_p195.csv
# S1_p281.csv
# S1_p202.csv
# S1_p62.csv
# S1_p138.csv
# S1_p236.csv
# S1_p252.csv
# S1_p200.csv
# S1_p275.csv
# S1_p164.csv
# S1_p270.csv
# S1_p17.csv
# S1_p277.csv
# S1_p279.csv
# S1_p58.csv
# S1_p112.csv
# S1_p45.csv
# S1_p36.csv
# S1_p2.csv
# S1_p169.csv
# S1_p127.csv
# S1_p59.csv
# S1_p246.csv
# S1_p292.csv
# S1_p77.csv
# S1_p13.csv
# S1_p233.csv
# S1_p160.csv
# S1_p231.csv
# S1_p23.csv
# S1_p177.csv
# S1_p253.csv
# S1_p265.csv
# S1_p299.csv
# S1_p217.csv
# S1_p94.csv
# S1_p193.csv
# S1_p229.csv
# S1_p197.csv
# S1_p122.csv
# S1_p91.csv
# S1_p224.csv
# S1_p3.csv
# S1_p163.csv
# S1_p196.csv
# S1_p76.csv
# ...
